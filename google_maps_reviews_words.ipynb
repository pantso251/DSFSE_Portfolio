# %% [markdown]
# <a href="https://colab.research.google.com/github/pantso251/DSFSE_Portfolio/blob/main/google_maps_reviews_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WHAT THIS CODE DOES?
#
# This code is used as an extension to the Google Maps Places where here I add the feature to extract specific keywords from the first 5-10 comments from Google Reviews. These keywords may contain letters regarding beach pollution and its scale (e.g clean, dirty, plastic, pollution etc.) Italian comments are directly translated to eng while we provide some additional words in Italian language for better accuracy.

# %%
import pandas as pd
import requests
import time
import re
from collections import Counter

# ==================== CONFIGURATION ====================
GOOGLE_API_KEY = "AIzaSyD4zNLt3VtqjGW7ZYDRbGG8lQSvsdY4htA"  # Replace with your key
INPUT_FILE = "merged_dataset_v2.csv"
OUTPUT_FILE = "beach_google_reviews.csv"
NUM_BEACHES = 210

# ==================== KEYWORD DICTIONARY ====================
POLLUTION_KEYWORDS = {
    "clean": [
        # English stems
        "clean", "pristine", "spotless", "clear", "crystal",
        "tidy", "maintain", "sparkl",
        # Italian stems
        "pulit",  # pulito/pulita/puliti/pulite
        "cristall",  # cristallino/cristallina
        "limp",  # limpido/limpida
        "trasparent",  # trasparente
        "curat"  # curato/curata
    ],

    "dirty": [
        # English stems
        "dirt", "trash", "garbage", "litter", "pollut",
        "waste", "plastic", "bottl", "rubbish", "debris", "filth", "mess",
        # Italian stems
        "spor",  # sporco/sporca
        "spazzatur",  # spazzatura
        "rifiut",  # rifiuti
        "plastic",  # plastica/plastiche
        "bottigl",  # bottiglia/bottiglie
        "immondi",  # immondizia
        "inquin"  # inquinato/inquinata/inquinamento
    ],

    "crowded": [
        "crowd", "pack", "busy", "full", "overc", "too many",
        "affoll",  # affollato/affollata
        "pien",  # pieno/piena
        "sovraffoll",  # sovraffollato
        "troppa gente"
    ],

    "beautiful": [
        "beautiful", "gorgeous", "stunning", "amazing", "paradise", "wonderful",
        "bell",  # bello/bella/belli/belle/bellissimo
        "meraviglios",  # meraviglioso/meravigliosa
        "stupend",  # stupendo/stupenda
        "paradis"  # paradise/paradiso
    ]
}

# Negation words
NEGATIONS = ["not", "no", "never", "wasn't", "weren't", "isn't", "aren't",
             "non", "senza", "mai"]  # Italian: non, without, never

# ==================== FUNCTIONS ====================

def find_place_id(beach_name, lat, lng, api_key):
    """
    Find Google Place ID using Nearby Search
    """
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    params = {
        "location": f"{lat},{lng}", # Changed 'lon' to 'lng'
        "radius": "200",  # 200 meters
        "keyword": beach_name,
        "key": api_key
    }

    try:
        response = requests.get(url, params=params)
        data = response.json()

        if data.get("status") == "OK" and data.get("results"):
            return data["results"][0]["place_id"]
        else:
            print(f"    No place found. Status: {data.get('status')}")
            return None
    except Exception as e:
        print(f"    Error finding place: {e}")
        return None


def get_place_reviews(place_id, api_key):
    """
    Get place details including reviews (up to 5)
    """
    url = "https://maps.googleapis.com/maps/api/place/details/json"

    params = {
        "place_id": place_id,
        "fields": "name,rating,user_ratings_total,reviews",
        "key": api_key,
        "language": "en"  # Request English, but will get mixed languages
    }

    try:
        response = requests.get(url, params=params)
        data = response.json()

        if data.get("status") == "OK":
            result = data.get("result", {})
            return {
                "name": result.get("name"),
                "rating": result.get("rating"),
                "total_reviews": result.get("user_ratings_total"),
                "reviews": result.get("reviews", [])
            }
        else:
            print(f"    Error getting details. Status: {data.get('status')}")
            return None
    except Exception as e:
        print(f"    Error getting reviews: {e}")
        return None


def check_negation_context(sentence, keyword):
    """
    Check if keyword appears in a negated context
    """
    # Look for negation words within 3 words before the keyword
    words = sentence.split()

    for i, word in enumerate(words):
        if keyword in word.lower():
            # Check previous 3 words for negation
            start = max(0, i - 3)
            context = words[start:i]

            if any(neg in " ".join(context).lower() for neg in NEGATIONS):
                return True

    return False


def analyze_keywords_in_reviews(reviews):
    """
    Extract and count keywords from reviews with negation handling
    """
    keyword_counts = {
        "clean": 0,
        "dirty": 0,
        "crowded": 0,
        "beautiful": 0
    }

    all_found_keywords = []
    review_languages = []
    review_ratings = []

    for review in reviews:
        text = review.get("text", "")
        text_lower = text.lower()
        rating = review.get("rating", 0)
        language = review.get("language", "unknown")

        review_languages.append(language)
        review_ratings.append(rating)

        # Split into sentences for negation detection
        sentences = re.split(r'[.!?;]', text_lower)

        # Check each keyword category
        for category, keywords in POLLUTION_KEYWORDS.items():
            for keyword in keywords:
                if keyword in text_lower:
                    # Check if it's negated
                    is_negated = False

                    for sentence in sentences:
                        if keyword in sentence:
                            if check_negation_context(sentence, keyword):
                                is_negated = True
                                break

                    if not is_negated:
                        keyword_counts[category] += 1
                        all_found_keywords.append(keyword)

    return {
        "counts": keyword_counts,
        "keywords_found": all_found_keywords,
        "languages": review_languages,
        "ratings": review_ratings
    }


def calculate_scores(place_data, keyword_analysis):
    """
    Calculate various quality scores
    """
    scores = {}

    # 1. Keyword-based cleanliness score
    clean_total = keyword_analysis["counts"]["clean"] + keyword_analysis["counts"]["dirty"]

    if clean_total > 0:
        scores["keyword_cleanliness"] = (
            keyword_analysis["counts"]["clean"] / clean_total * 100
        )
    else:
        scores["keyword_cleanliness"] = None

    # 2. Overall Google rating score
    if place_data.get("rating"):
        scores["rating_score"] = (place_data["rating"] / 5.0) * 100
    else:
        scores["rating_score"] = None

    # 3. Average review rating
    if keyword_analysis["ratings"]:
        avg_rating = sum(keyword_analysis["ratings"]) / len(keyword_analysis["ratings"])
        scores["review_avg_score"] = (avg_rating / 5.0) * 100
    else:
        scores["review_avg_score"] = None

    # 4. Composite score (weighted average of available scores)
    available_scores = []

    if scores["keyword_cleanliness"] is not None:
        available_scores.append((scores["keyword_cleanliness"], 0.4))
    if scores["rating_score"] is not None:
        available_scores.append((scores["rating_score"], 0.4))
    if scores["review_avg_score"] is not None:
        available_scores.append((scores["review_avg_score"], 0.2))

    if available_scores:
        total_weight = sum(w for _, w in available_scores)
        weighted_sum = sum(s * w for s, w in available_scores)
        scores["composite_score"] = weighted_sum / total_weight
    else:
        scores["composite_score"] = None

    return scores


# ==================== MAIN EXECUTION ====================

def main():
    print("="*70)
    print("BEACH REVIEW ANALYSIS - GOOGLE PLACES API")
    print("="*70)

    # Load CSV
    print(f"\nLoading beaches from {INPUT_FILE}...")
    df = pd.read_csv(INPUT_FILE)

    # Print columns to debug
    print("\nDataFrame columns:")
    print(df.columns)

    # Filter valid beaches
    valid_beaches = df[df['API_Beach_Name'].notna() & df['Original_Beach_Name'].notna()]
    print(f"Found {len(valid_beaches)} valid beaches in CSV")

    # Select first N beaches
    subset = valid_beaches.head(NUM_BEACHES).copy()
    print(f"Processing first {len(subset)} beaches...\n")

    results = []

    for index, row in subset.iterrows():
        beach_name = row['API_Beach_Name']
        original_name = row['Original_Beach_Name']
        lat = row['lat']
        lng = row['lon']
        google_rating = row.get('rating', None)
        google_review_count = row.get('user_ratings_total', None)

        print(f"\n{'='*70}")
        print(f"Beach #{index + 1}: {beach_name}")
        print(f"Original name: {original_name}")
        print(f"Location: ({lat}, {lng})")
        print(f"{'='*70}")

        # Step 1: Find place_id
        print("  🔍 Searching for place...")
        place_id = find_place_id(beach_name, lat, lng, GOOGLE_API_KEY)

        if not place_id:
            print("  ❌ Place not found. Skipping.")
            results.append({
                "Beach_Name": beach_name,
                "Original_Name": original_name,
                "Status": "place_not_found",
                "Google_Rating": google_rating,
                "Total_Review_Count": google_review_count
            })
            continue

        print(f"  ✅ Found place_id: {place_id}")

        # Step 2: Get reviews
        print("  📖 Fetching reviews...")
        place_data = get_place_reviews(place_id, GOOGLE_API_KEY)

        if not place_data:
            print("  ❌ Could not fetch reviews. Skipping.")
            results.append({
                "Beach_Name": beach_name,
                "Original_Name": original_name,
                "Place_ID": place_id,
                "Status": "reviews_unavailable",
                "Google_Rating": google_rating,
                "Total_Review_Count": google_review_count
            })
            continue

        reviews = place_data.get("reviews", [])
        print(f"  ✅ Retrieved {len(reviews)} reviews")

        if len(reviews) == 0:
            print("  ⚠️  No reviews available")
            results.append({
                "Beach_Name": beach_name,
                "Original_Name": original_name,
                "Place_ID": place_id,
                "Status": "no_reviews",
                "Google_Rating": place_data.get("rating"),
                "Total_Review_Count": place_data.get("total_reviews")
            })
            continue

        # Step 3: Analyze keywords
        print("  🔬 Analyzing keywords...")
        keyword_analysis = analyze_keywords_in_reviews(reviews)

        print(f"    Clean mentions: {keyword_analysis['counts']['clean']}")
        print(f"    Dirty mentions: {keyword_analysis['counts']['dirty']}")
        print(f"    Crowded mentions: {keyword_analysis['counts']['crowded']}")
        print(f"    Beautiful mentions: {keyword_analysis['counts']['beautiful']}")

        # Step 4: Calculate scores
        scores = calculate_scores(place_data, keyword_analysis)

        print(f"  📊 Scores:")
        if scores["keyword_cleanliness"] is not None:
            print(f"    Keyword cleanliness: {scores['keyword_cleanliness']:.1f}%")
        print(f"    Google rating: {place_data.get('rating')}/5 ({scores['rating_score']:.1f}%)")
        if scores["composite_score"] is not None:
            print(f"    Composite score: {scores['composite_score']:.1f}%")

        # Get top keywords
        keyword_counter = Counter(keyword_analysis['keywords_found'])
        top_keywords = dict(keyword_counter.most_common(5))

        # Determine data quality
        total_keywords = sum(keyword_analysis['counts'].values())
        if total_keywords > 5:
            data_quality = "high"
        elif total_keywords > 0:
            data_quality = "medium"
        else:
            data_quality = "rating_only"

        # Store results
        results.append({
            "Beach_Name": beach_name,
            "Original_Name": original_name,
            "Place_ID": place_id,
            "Status": "success",

            # Google data
            "Google_Rating": place_data.get("rating"),
            "Total_Review_Count": place_data.get("total_reviews"),
            "Reviews_Analyzed": len(reviews),

            # Keyword counts
            "Clean_Mentions": keyword_analysis['counts']['clean'],
            "Dirty_Mentions": keyword_analysis['counts']['dirty'],
            "Crowded_Mentions": keyword_analysis['counts']['crowded'],
            "Beautiful_Mentions": keyword_analysis['counts']['beautiful'],

            # Scores
            "Keyword_Cleanliness_Score": scores["keyword_cleanliness"],
            "Rating_Score": scores["rating_score"],
            "Composite_Score": scores["composite_score"],

            # Metadata
            "Data_Quality": data_quality,
            "Top_Keywords": str(top_keywords),
            "Languages": ", ".join(set(keyword_analysis['languages'])),

            # Location
            "Latitude": lat,
            "Longitude": lng
        })

        # Rate limiting
        time.sleep(1)

    # Save results
    print(f"\n{'='*70}")
    print("SAVING RESULTS")
    print(f"{'='*70}")

    results_df = pd.DataFrame(results)
    results_df.to_csv(OUTPUT_FILE, index=False)

    print(f"✅ Saved {len(results_df)} results to '{OUTPUT_FILE}'")

    # Summary statistics
    print(f"\n{'='*70}")
    print("SUMMARY")
    print(f"{'='*70}")

    successful = results_df[results_df['Status'] == 'success']
    print(f"Successful analyses: {len(successful)}/{len(results_df)}")

    if len(successful) > 0:
        print(f"\nData quality distribution:")
        print(successful['Data_Quality'].value_counts())

        print(f"\nAverage scores:")
        print(f"  Google rating: {successful['Google_Rating'].mean():.2f}/5")

        if successful['Composite_Score'].notna().any():
            print(f"  Composite score: {successful['Composite_Score'].mean():.1f}%")

        print(f"\nTop beaches by composite score:")
        top_beaches = successful.nlargest(5, 'Composite_Score')[
            ['Beach_Name', 'Composite_Score', 'Clean_Mentions', 'Dirty_Mentions']
        ]
        print(top_beaches.to_string(index=False))

    print(f"\n{'='*70}")
    print("ANALYSIS COMPLETE!")
    print(f"{'='*70}\n")

    return results_df


# Run the analysis
if __name__ == "__main__":
    results_df = main()
# Out:
# ======================================================================
# BEACH REVIEW ANALYSIS - GOOGLE PLACES API
# ======================================================================
#
# Loading beaches from merged_dataset_v2.csv...
#
# DataFrame columns:
# Index(['Unnamed: 0', 'Beach_Code', 'Original_Beach_Name', 'API_Beach_Name',
#        'rating', 'user_ratings_total', 'lat', 'lon', 'Date of collection',
#        'Period', 'length', 'Trash amount', 'Beach was cleaned',
#        'The last time that beach has been cleaned',
#        'The last time that was cleaned from another group',
#        'further from the reference point above 100 meters ',
#        'Trovato un animale abbandonato o morto',
#        'Numero di animali abbandonati o morti'],
#       dtype='object')
# Found 189 valid beaches in CSV
# Processing first 189 beaches...
#
#
# ======================================================================
# Beach #1: Spiaggia Aciddara
# Original name: Aciddara
# Location: (38.08036623, 13.53734493)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJsUOqHnziGRMRDGtnm_hY-70
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 42.9%
#     Google rating: 3.5/5 (70.0%)
#     Composite score: 54.7%
#
# ======================================================================
# Beach #2: Spiaggia Aciddara
# Original name: Aciddara
# Location: (38.08036623, 13.53734493)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJsUOqHnziGRMRDGtnm_hY-70
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 42.9%
#     Google rating: 3.5/5 (70.0%)
#     Composite score: 54.7%
#
# ======================================================================
# Beach #3: Spiaggia Aciddara
# Original name: Aciddara
# Location: (38.08036623, 13.53734493)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJsUOqHnziGRMRDGtnm_hY-70
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 42.9%
#     Google rating: 3.5/5 (70.0%)
#     Composite score: 54.7%
#
# ======================================================================
# Beach #4: Capo di Sorrento
# Original name: Bagni della Regina Giovanna - Sorrento (Na)
# Location: (40.63355879, 14.35122371)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJv1MCIqafOxMRcHpfc7L9KQY
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 1
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 96.0%
#
# ======================================================================
# Beach #5: Spiaggia Libera Steccato di Cutro
# Original name: Boschetto Steccato di Cutro
# Location: (38.93462782, 16.93195671)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #6: Spiaggia Libera Steccato di Cutro
# Original name: Boschetto Steccato di Cutro
# Location: (38.93462782, 16.93195671)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #7: Torre Cala Santa Maria
# Original name: Cala Santa Maria
# Location: (38.70891163, 13.19533405)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJW146RsY3GBMRYIei9mRCaSY
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Google rating: 4/5 (80.0%)
#     Composite score: 80.0%
#
# ======================================================================
# Beach #8: Punta Penna Grossa Beach
# Original name: Caletta Caretta
# Location: (40.72236478, 17.77187437)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJWwm6Ei9vRhMRCppS1n2Pdl4
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 33.3%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 66.1%
#
# ======================================================================
# Beach #9: Punta Penna Grossa Beach
# Original name: Caletta Caretta
# Location: (40.72236478, 17.77187437)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJWwm6Ei9vRhMRCppS1n2Pdl4
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 33.3%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 66.1%
#
# ======================================================================
# Beach #10: Sant'Elia
# Original name: Caletta di Sant'Elia
# Location: (38.09654187, 13.53882176)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ25RBAnTiGRMRXnh1p4WoSfs
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 1
#     Crowded mentions: 0
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4.6/5 (92.0%)
#     Composite score: 82.7%
#
# ======================================================================
# Beach #11: Sant'Elia
# Original name: Caletta di Sant'Elia
# Location: (38.09654187, 13.53882176)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ25RBAnTiGRMRXnh1p4WoSfs
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 1
#     Crowded mentions: 0
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4.6/5 (92.0%)
#     Composite score: 82.7%
#
# ======================================================================
# Beach #12: Buddha Beach
# Original name: Capo Arena- budda beach
# Location: (39.87517777, 1.57836628)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #13: Spiaggia di Santa Severa
# Original name: Castello di Santa Severa
# Location: (42.01692123, 11.95644021)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJf17pPMeuKBMRdg8SBm8cPh4
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 0
#     Crowded mentions: 5
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 89.6%
#
# ======================================================================
# Beach #14: Spiaggia di Santa Severa
# Original name: Castello di Santa Severa
# Location: (42.01692123, 11.95644021)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJf17pPMeuKBMRdg8SBm8cPh4
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 0
#     Crowded mentions: 5
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 89.6%
#
# ======================================================================
# Beach #15: Spiaggia di Santa Severa
# Original name: Castello di Santa Severa
# Location: (42.01692123, 11.95644021)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJf17pPMeuKBMRdg8SBm8cPh4
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 0
#     Crowded mentions: 5
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 89.6%
#
# ======================================================================
# Beach #16: Spiaggia Rocco dei Matti
# Original name: Caulonia
# Location: (38.33758366, 16.46034821)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #17: Spiaggia Rocco dei Matti
# Original name: Caulonia
# Location: (38.33758366, 16.46034821)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #18: Spiaggia di Cipollazzo
# Original name: Cipollazzo
# Location: (37.57328088, 12.93836474)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJdf9DlPxJGhMRlNklfbLnPfU
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.6/5 (92.0%)
#     Composite score: 96.8%
#
# ======================================================================
# Beach #19: Spiaggia di Cipollazzo
# Original name: Cipollazzo
# Location: (37.57328088, 12.93836474)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJdf9DlPxJGhMRlNklfbLnPfU
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.6/5 (92.0%)
#     Composite score: 96.8%
#
# ======================================================================
# Beach #20: Spiaggia di Cipollazzo
# Original name: Cipollazzo
# Location: (37.57328088, 12.93836474)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJdf9DlPxJGhMRlNklfbLnPfU
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.6/5 (92.0%)
#     Composite score: 96.8%
#
# ======================================================================
# Beach #21: Spiaggia libera
# Original name: Club Adriatico - Polignano a Mare
# Location: (41.02005106, 17.18505156)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #22: Spiaggia La PINETA
# Original name: da Marinella di Selinunte alla Foce del Fiume Belice, sponda destra e sinistra verso Menfi
# Location: (37.58125831, 12.85864681)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #23: Spiaggia Praia
# Original name: Favignana
# Location: (37.92938738, 12.32539415)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJtZ0RmfLjGxMRUMsY_jl7Sfg
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 3
#     Crowded mentions: 1
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 25.0%
#     Google rating: 3.9/5 (78.0%)
#     Composite score: 54.0%
#
# ======================================================================
# Beach #24: Spiaggia Praia
# Original name: Favignana
# Location: (37.92938738, 12.32539415)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJtZ0RmfLjGxMRUMsY_jl7Sfg
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 3
#     Crowded mentions: 1
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 25.0%
#     Google rating: 3.9/5 (78.0%)
#     Composite score: 54.0%
#
# ======================================================================
# Beach #25: Fiume Savuto
# Original name: Foce del Savuto
# Location: (39.03850398, 16.09786749)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #26: Fiume Savuto
# Original name: Foce del Savuto
# Location: (39.03850398, 16.09786749)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #27: Spiaggia Funcitedda
# Original name: Fungitedda
# Location: (37.36028621, 13.34593821)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJgz9SrTtlGhMRs7MxI-vOAR8
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 1
#     Crowded mentions: 2
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 50.0%
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 76.8%
#
# ======================================================================
# Beach #28: Lido Gizzeria - Spiaggia libera
# Original name: Gizzeria Lido
# Location: (38.92817526, 16.21443059)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJU4SrXzvnPxMReThUs1gzVtU
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 0.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 53.6%
#
# ======================================================================
# Beach #29: Lido Gizzeria - Spiaggia libera
# Original name: Gizzeria Lido
# Location: (38.92817526, 16.21443059)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJU4SrXzvnPxMReThUs1gzVtU
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 4
#     Crowded mentions: 2
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 0.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 53.6%
#
# ======================================================================
# Beach #30: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #31: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #32: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #33: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #34: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #35: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #36: Isola Sant'Andrea
# Original name: isola di Sant'Andrea
# Location: (40.66103311, 17.96886921)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #37: Spiaggia Libera
# Original name: l'amanusa spiaggia libera
# Location: (4.17030752, 12.33833179)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #38: Spiaggia di Cala Minnola
# Original name: Levanzo
# Location: (37.98983033, 12.34538761)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #39: Torre a Mare
# Original name: Lido azzurro e ske torre a mare bari
# Location: (41.08838011, 17.00377285)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJcdPcr3nDRxMRFnfTcyLk8cE
#   📖 Fetching reviews...
#   ✅ Retrieved 0 reviews
#   ⚠️  No reviews available
#
# ======================================================================
# Beach #40: pontile di ostia
# Original name: Lido di Ostia
# Location: (41.72356556, 12.29061985)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJs2oYGQDvJRMRlTimq4HWdzY
#   📖 Fetching reviews...
#   ✅ Retrieved 3 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 93.8%
#
# ======================================================================
# Beach #41: pontile di ostia
# Original name: Lido di Ostia
# Location: (41.72356556, 12.29061985)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJs2oYGQDvJRMRlTimq4HWdzY
#   📖 Fetching reviews...
#   ✅ Retrieved 3 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 93.8%
#
# ======================================================================
# Beach #42: pontile di ostia
# Original name: Lido di Ostia
# Location: (41.72356556, 12.29061985)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJs2oYGQDvJRMRlTimq4HWdzY
#   📖 Fetching reviews...
#   ✅ Retrieved 3 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 93.8%
#
# ======================================================================
# Beach #43: Spiaggia Lido Fiori
# Original name: Lido Fiori
# Location: (37.56608553, 12.95526266)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJkcm7D21JGhMRi62kqlxWJ1w
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 5
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.5/5 (90.0%)
#     Composite score: 96.0%
#
# ======================================================================
# Beach #44: Spiaggia Lido Fiori
# Original name: Lido Fiori
# Location: (37.56608553, 12.95526266)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJkcm7D21JGhMRi62kqlxWJ1w
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 5
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.5/5 (90.0%)
#     Composite score: 96.0%
#
# ======================================================================
# Beach #45: Spiaggia Lido Fiori
# Original name: Lido Fiori
# Location: (37.56608553, 12.95526266)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJkcm7D21JGhMRi62kqlxWJ1w
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 5
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.5/5 (90.0%)
#     Composite score: 96.0%
#
# ======================================================================
# Beach #46: Spiaggia Libera-Lungomare di Sabaudia
# Original name: Lungomare di Sabaudia
# Location: (0.04131036, 0.13001345)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #47: Spiaggia di San Montano
# Original name: Marina della Lobra - Miglio Blu - Massa Lubrense (Na)
# Location: (4.06146022, 14.33898211)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #48: Spiaggia di San Montano
# Original name: Marina della Lobra - Miglio Blu - Massa Lubrense (Na)
# Location: (4.06146022, 14.33898211)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #49: Spiaggia Marina di Pisa
# Original name: Marina di Pisa
# Location: (4.3e-07, 1e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #50: Spiaggia Marina di Pisa
# Original name: Marina di Pisa
# Location: (4.3e-07, 1e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #51: Spiaggia della Marinella di San Terenzo
# Original name: Marinella di San Terenzo
# Location: (44.08305164, 98.94803166)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #52: Spiaggia di Mondragone
# Original name: Mondragone Spiaggia Lungomare Sinope
# Location: (0.00411107, 0.00138876)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #53: Spiaggia di Mondragone
# Original name: Mondragone Spiaggia Lungomare Sinope
# Location: (0.00411107, 0.00138876)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #54: Fiumarella(Spiaggia libera)
# Original name: Mondragone zona Fiumarella
# Location: (41.11944311, 1.38711496)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #55: Fiumarella(Spiaggia libera)
# Original name: Mondragone zona Fiumarella
# Location: (41.11944311, 1.38711496)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #56: Oasi dei variconi
# Original name: Oasi dei Variconi
# Location: (4.102103000000001e-07, 1.392991304e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #57: Oasi dei variconi
# Original name: Oasi dei Variconi
# Location: (4.102103000000001e-07, 1.392991304e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #58: Oasi dei variconi
# Original name: Oasi dei Variconi
# Location: (4.102103000000001e-07, 1.392991304e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #59: Oasi dei variconi
# Original name: Oasi dei Variconi
# Location: (4.102103000000001e-07, 1.392991304e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #60: Oasi dei variconi
# Original name: Oasi dei Variconi
# Location: (4.102103000000001e-07, 1.392991304e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #61: Oasi del Fratino e della Camomilla di mare
# Original name: Oasi del Fratino e della Camomilla di mare
# Location: (42.74993435, 1.39741652)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #62: Oasi del Fratino e della Camomilla di mare
# Original name: Oasi del Fratino e della Camomilla di mare
# Location: (42.74993435, 1.39741652)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #63: Oasis of Bosco Pantano
# Original name: Oasi WWF Bosco Pantano
# Location: (40.16945502, 16.70136452)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJp_5AAMlRRxMR_1Um97bRXzw
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 1
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.5/5 (90.0%)
#     Composite score: 95.2%
#
# ======================================================================
# Beach #64: Oasis of Bosco Pantano
# Original name: Oasi WWF Bosco Pantano
# Location: (40.16945502, 16.70136452)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJp_5AAMlRRxMR_1Um97bRXzw
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 1
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.5/5 (90.0%)
#     Composite score: 95.2%
#
# ======================================================================
# Beach #65: Oasis of Bosco Pantano
# Original name: Oasi WWF Bosco Pantano
# Location: (40.16945502, 16.70136452)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJp_5AAMlRRxMR_1Um97bRXzw
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 1
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.5/5 (90.0%)
#     Composite score: 95.2%
#
# ======================================================================
# Beach #66: Spiaggia libera Le Dune
# Original name: oasi wwf dune di forte dei marmi ( LU )
# Location: (43.97447147, 10.14483225)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJiUvL15cJ1RIRoo2liC2JVWE
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4/5 (80.0%)
#     Composite score: 88.8%
#
# ======================================================================
# Beach #67: Spiaggia libera Le Dune
# Original name: oasi wwf dune di forte dei marmi ( LU )
# Location: (43.97447147, 10.14483225)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJiUvL15cJ1RIRoo2liC2JVWE
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4/5 (80.0%)
#     Composite score: 88.8%
#
# ======================================================================
# Beach #68: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #69: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #70: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #71: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #72: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #73: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #74: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #75: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #76: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #77: Spiaggia Lago di Burano
# Original name: Oasi WWF Lago di Burano
# Location: (4.23962697, 11.37677193)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #78: Alberoni Sand Dune Oasis
# Original name: Oasi ZSC ZPS Dune Alberoni
# Location: (45.34678248, 12.32945395)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJeyHu_t6kfkcRzVZPPDcYVsc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 1
#     Crowded mentions: 1
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4.3/5 (86.0%)
#     Composite score: 78.7%
#
# ======================================================================
# Beach #79: Alberoni Sand Dune Oasis
# Original name: Oasi ZSC ZPS Dune Alberoni
# Location: (45.34678248, 12.32945395)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJeyHu_t6kfkcRzVZPPDcYVsc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 1
#     Crowded mentions: 1
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4.3/5 (86.0%)
#     Composite score: 78.7%
#
# ======================================================================
# Beach #80: Spiaggia Mendolido
# Original name: Plage de Eduard
# Location: (38.03314178, 13.97037685)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJRSMoEgU5FxMRHMsrSDmOtzA
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 3.9/5 (78.0%)
#     Composite score: 88.8%
#
# ======================================================================
# Beach #81: Spiaggia Mendolido
# Original name: Plage de Eduard
# Location: (38.03314178, 13.97037685)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJRSMoEgU5FxMRHMsrSDmOtzA
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 1
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 3.9/5 (78.0%)
#     Composite score: 88.8%
#
# ======================================================================
# Beach #82: Spiaggia di Catania
# Original name: Playa Catania
# Location: (3.74425e-07, 1.508585777e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #83: Spiaggia di Catania
# Original name: Playa Catania
# Location: (3.74425e-07, 1.508585777e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #84: Spiaggia di Catania
# Original name: Playa Catania
# Location: (3.74425e-07, 1.508585777e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #85: Spiaggia di porto caleri
# Original name: Porto Caleri
# Location: (45.10055917, 12.33449933)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #86: Spiaggia di porto caleri
# Original name: Porto Caleri
# Location: (45.10055917, 12.33449933)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #87: Spiaggia di porto caleri
# Original name: Porto Caleri
# Location: (45.10055917, 12.33449933)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #88: Spiaggia di porto caleri
# Original name: Porto Caleri
# Location: (45.10055917, 12.33449933)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #89: Spiaggia Porto Empedocle
# Original name: Porto Empedocle
# Location: (37.28596494, 13.52270007)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #90: Spiaggia Libera - Steccato di Cutro
# Original name: Porto Kaleo
# Location: (38.93326742, 16.92242146)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ2Y6O5HA9QBMRc8kpNuvnRHc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 93.6%
#
# ======================================================================
# Beach #91: Spiaggia Libera - Steccato di Cutro
# Original name: Porto Kaleo
# Location: (38.93326742, 16.92242146)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ2Y6O5HA9QBMRc8kpNuvnRHc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 93.6%
#
# ======================================================================
# Beach #92: Spiaggia Libera - Steccato di Cutro
# Original name: Porto Kaleo
# Location: (38.93326742, 16.92242146)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ2Y6O5HA9QBMRc8kpNuvnRHc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 93.6%
#
# ======================================================================
# Beach #93: Spiaggia Libera - Steccato di Cutro
# Original name: Porto Kaleo
# Location: (38.93326742, 16.92242146)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ2Y6O5HA9QBMRc8kpNuvnRHc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 93.6%
#
# ======================================================================
# Beach #94: Spiaggia Libera - Steccato di Cutro
# Original name: Porto Kaleo
# Location: (38.93326742, 16.92242146)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ2Y6O5HA9QBMRc8kpNuvnRHc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 93.6%
#
# ======================================================================
# Beach #95: Spiaggia di Porto Palo
# Original name: Porto palo
# Location: (37.57728601, 12.90381789)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #96: Spiaggia di Porto Palo
# Original name: Porto palo
# Location: (37.57728601, 12.90381789)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #97: Spiaggia di Porto Palo
# Original name: Porto palo
# Location: (37.57728601, 12.90381789)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #98: Punta Penna Grossa Beach
# Original name: Punta Penna Grossa
# Location: (40.71863493, 17.78295457)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #99: Punta Penna Grossa Beach
# Original name: Punta Penna Grossa
# Location: (40.71863493, 17.78295457)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #100: Torre Guaceto beach
# Original name: Quarta caletta
# Location: (40.71587662, 1.77929163)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #101: Torre Guaceto beach
# Original name: Quarta caletta
# Location: (40.71587662, 1.77929163)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #102: Riserva Naturale del Borsacchio
# Original name: RISERVA BORSACCHIO
# Location: (42.70534557, 13.99978635)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #103: Riserva Naturale del Borsacchio
# Original name: RISERVA BORSACCHIO
# Location: (42.70534557, 13.99978635)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #104: Riserva Naturale del Borsacchio
# Original name: RISERVA BORSACCHIO
# Location: (42.70534557, 13.99978635)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #105: Riserva Naturale del Borsacchio
# Original name: RISERVA BORSACCHIO
# Location: (42.70534557, 13.99978635)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #106: Riserva Naturale del Borsacchio
# Original name: RISERVA BORSACCHIO
# Location: (42.70534557, 13.99978635)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #107: Riserva Naturale del Borsacchio
# Original name: RISERVA BORSACCHIO
# Location: (42.70534557, 13.99978635)
# ======================================================================
# ...
# Original name: Spiaggia libera - Braccio Levante Barletta
# Location: (41.32015533, 16.29944086)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJwQMAxmEcOBMRFpDB1BJLTEk
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 1
#     Crowded mentions: 0
#     Beautiful mentions: 2
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 73.1%
#
# ======================================================================
# Beach #158: Bagno Spiaggia Libera
# Original name: Spiaggia libera di Igea Marina
# Location: (4.41167876, 12.50289738)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #159: Passeggiata di Corso Italia
# Original name: Spiaggia Libera di Punta Vagno
# Location: (44.39324932, 89.49779391)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #160: Passeggiata di Corso Italia
# Original name: Spiaggia Libera di Punta Vagno
# Location: (44.39324932, 89.49779391)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #161: Spiaggia Le Colonie
# Original name: Spiaggia libera Marano - colonia Bolognese
# Location: (44.02347862, 12.63465285)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ3204KjrdLBMRnnLHyLzqbQ0
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 94.7%
#
# ======================================================================
# Beach #162: Spiaggia Le Colonie
# Original name: Spiaggia libera Marano - colonia Bolognese
# Location: (44.02347862, 12.63465285)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ3204KjrdLBMRnnLHyLzqbQ0
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 94.7%
#
# ======================================================================
# Beach #163: Spiaggia Le Colonie
# Original name: Spiaggia libera Marano - colonia Bolognese
# Location: (44.02347862, 12.63465285)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJ3204KjrdLBMRnnLHyLzqbQ0
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 0
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Google rating: 4.7/5 (94.0%)
#     Composite score: 94.7%
#
# ======================================================================
# Beach #164: Lido La Duna Policoro
# Original name: Spiaggia Lido La Duna
# Location: (4.01770107, 1.67088747)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #165: Lido La Duna Policoro
# Original name: Spiaggia Lido La Duna
# Location: (4.01770107, 1.67088747)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #166: Spiaggia libera Bianca- L’Amanusa
# Original name: SPIAGGIA  LUNGOMARE AMERIGO VESPUCCI LIDO DI CASTELFUSANO
# Location: (41.70291379, 12.33860725)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJQ1D13XPuJRMRzHlzH3uNBfY
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 0
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 91.2%
#
# ======================================================================
# Beach #167: Lido Morelli
# Original name: Spiaggia nel Parco delle Dune Costiere
# Location: (40.81025258, 17.52622962)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJv8XFg35GRhMRvdpnWzfQziY
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 2
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 89.6%
#
# ======================================================================
# Beach #168: Lido Morelli
# Original name: Spiaggia nel Parco delle Dune Costiere
# Location: (40.81025258, 17.52622962)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJv8XFg35GRhMRvdpnWzfQziY
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 2
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 89.6%
#
# ======================================================================
# Beach #169: Lido Morelli
# Original name: Spiaggia nel Parco delle Dune Costiere
# Location: (40.81025258, 17.52622962)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJv8XFg35GRhMRvdpnWzfQziY
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 2
#     Dirty mentions: 0
#     Crowded mentions: 2
#     Beautiful mentions: 0
#   📊 Scores:
#     Keyword cleanliness: 100.0%
#     Google rating: 4.1/5 (82.0%)
#     Composite score: 89.6%
#
# ======================================================================
# Beach #170: Spiaggia - Ombelico di Venere
# Original name: Spiaggia Ombelico di Venere
# Location: (3.80295527, 13.58817977)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #171: Spiaggia - Ombelico di Venere
# Original name: Spiaggia Ombelico di Venere
# Location: (3.80295527, 13.58817977)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #172: Sabbie Nere Santa Severa
# Original name: Spiaggia Sabbie Nere Santa Severa
# Location: (42.01371519, 11.96492672)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJzV8KarCuKBMRxsVQ1slVbSc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 1
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 75.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 83.6%
#
# ======================================================================
# Beach #173: Sabbie Nere Santa Severa
# Original name: Spiaggia Sabbie Nere Santa Severa
# Location: (42.01371519, 11.96492672)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJzV8KarCuKBMRxsVQ1slVbSc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 1
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 75.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 83.6%
#
# ======================================================================
# Beach #174: Sabbie Nere Santa Severa
# Original name: Spiaggia Sabbie Nere Santa Severa
# Location: (42.01371519, 11.96492672)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJzV8KarCuKBMRxsVQ1slVbSc
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 3
#     Dirty mentions: 1
#     Crowded mentions: 0
#     Beautiful mentions: 1
#   📊 Scores:
#     Keyword cleanliness: 75.0%
#     Google rating: 4.4/5 (88.0%)
#     Composite score: 83.6%
#
# ======================================================================
# Beach #175: Spiaggia Salinelle
# Original name: Spiaggia Salinelle
# Location: (3.80202957, 13.93190002)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #176: Spiaggia Salinelle
# Original name: Spiaggia Salinelle
# Location: (3.80202957, 13.93190002)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #177: Lungomare Di Strongoli Marina
# Original name: Strongoli marina
# Location: (3.92538e-07, 1.710645e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #178: Lungomare Di Strongoli Marina
# Original name: Strongoli marina
# Location: (3.92538e-07, 1.710645e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #179: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #180: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #181: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #182: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #183: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #184: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #185: Feniglia
# Original name: Tombolo della Feniglia
# Location: (0.04241862, 0.01124465)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: ZERO_RESULTS
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #186: Spiaggia libera Le Dune
# Original name: trabucco
# Location: (4.398257e-07, 1.013512e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #187: Spiaggia libera Le Dune
# Original name: trabucco
# Location: (4.398257e-07, 1.013512e-07)
# ======================================================================
#   🔍 Searching for place...
#     No place found. Status: INVALID_REQUEST
#   ❌ Place not found. Skipping.
#
# ======================================================================
# Beach #188: Spiaggia Vergine Maria
# Original name: Vergine Maria
# Location: (38.16625971, 13.36852026)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJkbZfDCXmGRMRMlocdiAMU14
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 4
#     Dirty mentions: 2
#     Crowded mentions: 2
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4/5 (80.0%)
#     Composite score: 75.5%
#
# ======================================================================
# Beach #189: Spiaggia Vergine Maria
# Original name: Vergine Maria
# Location: (38.16625971, 13.36852026)
# ======================================================================
#   🔍 Searching for place...
#   ✅ Found place_id: ChIJkbZfDCXmGRMRMlocdiAMU14
#   📖 Fetching reviews...
#   ✅ Retrieved 5 reviews
#   🔬 Analyzing keywords...
#     Clean mentions: 4
#     Dirty mentions: 2
#     Crowded mentions: 2
#     Beautiful mentions: 4
#   📊 Scores:
#     Keyword cleanliness: 66.7%
#     Google rating: 4/5 (80.0%)
#     Composite score: 75.5%
#
# ======================================================================
# SAVING RESULTS
# ======================================================================
# ✅ Saved 189 results to 'beach_google_reviews.csv'
#
# ======================================================================
# SUMMARY
# ======================================================================
# Successful analyses: 67/189
#
# Data quality distribution:
# Data_Quality
# medium         39
# high           24
# rating_only     4
# Name: count, dtype: int64
#
# Average scores:
#   Google rating: 4.31/5
#   Composite score: 79.5%
#
# Top beaches by composite score:
#                             Beach_Name  Composite_Score  Clean_Mentions  Dirty_Mentions
# Antemurale Porticciolo Santa Marinella            100.0             0.0             0.0
#                 Spiaggia di Cipollazzo             96.8             1.0             0.0
#                 Spiaggia di Cipollazzo             96.8             1.0             0.0
#                 Spiaggia di Cipollazzo             96.8             1.0             0.0
#                       Capo di Sorrento             96.0             2.0             0.0
#
# ======================================================================
# ANALYSIS COMPLETE!
# ======================================================================

# %%
# API key froze, just checking if it still works.
import requests


url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "41.9028,12.4964",  # Rome
    "radius": "500",
    "keyword": "colosseum",
    "key": GOOGLE_API_KEY
}

response = requests.get(url, params=params)
print(response.json())
# Out:
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
